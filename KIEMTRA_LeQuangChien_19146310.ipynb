# %% [markdown]
# <a href="https://colab.research.google.com/github/QuangLe102/AI/blob/main/KIEMTRA_LeQuangChien_19146310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Thư viện

# %%
import cv2
import sklearn
import numpy as np
import pandas as pd
import pickle
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from keras.utils import np_utils
from keras.models import Sequential
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam, RMSprop
from keras.layers import Dense, Activation, Dropout,Flatten, Conv2D,MaxPooling2D
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.optimizers import Adam, RMSprop,SGD

# %% [markdown]
# # Load và xử lý data

# %%
with open('Nhandiencamxuc_CNN.pickle', 'rb') as f:
    (x_train, y_train) = pickle.load(f)
x_pre = x_train

# %%
x_train = x_train.astype('float32')
x_train /= 255
y_train = to_categorical(y_train, 4)

# %% [markdown]
# # Tạo model

# %%
model = Sequential()
model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same', input_shape = (150, 150, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(MaxPooling2D((2, 2)))

#ANN
model.add(Flatten())
model.add(Dense(64, activation = 'relu', kernel_initializer= 'he_uniform'))
model.add(Dense(128, activation = 'relu', kernel_initializer= 'he_uniform'))
model.add(Dense(4, activation= 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 150, 150, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 37, 37, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 128)       147584
#
#  max_pooling2d_6 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 10368)             0
#
#  dense_3 (Dense)             (None, 64)                663616
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 913,284
# Trainable params: 913,284
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile và train

# %%
opt = SGD(lr = 0.01, momentum = 0.9)
model.compile(optimizer = opt, loss = 'categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train, y_train, epochs = 100, batch_size=64, verbose = 1)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 2/2 [==============================] - 4s 1s/step - loss: 2.7394 - accuracy: 0.2088
# Epoch 2/100
# 2/2 [==============================] - 4s 1s/step - loss: 4.3147 - accuracy: 0.2308
# Epoch 3/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.4647 - accuracy: 0.2747
# Epoch 4/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3969 - accuracy: 0.2527
# Epoch 5/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3854 - accuracy: 0.2637
# Epoch 6/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3854 - accuracy: 0.2967
# Epoch 7/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3825 - accuracy: 0.3187
# Epoch 8/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3837 - accuracy: 0.2308
# Epoch 9/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3789 - accuracy: 0.2747
# Epoch 10/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3706 - accuracy: 0.3407
# Epoch 11/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3643 - accuracy: 0.2637
# Epoch 12/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3712 - accuracy: 0.2967
# Epoch 13/100
# 2/2 [==============================] - 5s 1s/step - loss: 1.3568 - accuracy: 0.2747
# Epoch 14/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3637 - accuracy: 0.3077
# Epoch 15/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3507 - accuracy: 0.4176
# Epoch 16/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3454 - accuracy: 0.3846
# Epoch 17/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3265 - accuracy: 0.3407
# Epoch 18/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3284 - accuracy: 0.3516
# Epoch 19/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3161 - accuracy: 0.4615
# Epoch 20/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3008 - accuracy: 0.3297
# Epoch 21/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.4888 - accuracy: 0.2308
# Epoch 22/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.4083 - accuracy: 0.3407
# Epoch 23/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3507 - accuracy: 0.2637
# Epoch 24/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3144 - accuracy: 0.4176
# Epoch 25/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3619 - accuracy: 0.3516
# Epoch 26/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2964 - accuracy: 0.3407
# Epoch 27/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3628 - accuracy: 0.2747
# Epoch 28/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3021 - accuracy: 0.3956
# Epoch 29/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2937 - accuracy: 0.3626
# Epoch 30/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2682 - accuracy: 0.4396
# Epoch 31/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2613 - accuracy: 0.3736
# Epoch 32/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2550 - accuracy: 0.3736
# Epoch 33/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2545 - accuracy: 0.3626
# Epoch 34/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2246 - accuracy: 0.4505
# Epoch 35/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2127 - accuracy: 0.4945
# Epoch 36/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.1435 - accuracy: 0.5385
# Epoch 37/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2573 - accuracy: 0.3736
# Epoch 38/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.1484 - accuracy: 0.3956
# Epoch 39/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.1703 - accuracy: 0.4615
# Epoch 40/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.0768 - accuracy: 0.5714
# Epoch 41/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.1074 - accuracy: 0.4615
# Epoch 42/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.0575 - accuracy: 0.5385
# Epoch 43/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.0218 - accuracy: 0.6044
# Epoch 44/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.9305 - accuracy: 0.6154
# Epoch 45/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.8575 - accuracy: 0.6374
# Epoch 46/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.8403 - accuracy: 0.7033
# Epoch 47/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.7628 - accuracy: 0.6813
# Epoch 48/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.8357 - accuracy: 0.6374
# Epoch 49/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.7652 - accuracy: 0.7033
# Epoch 50/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.7665 - accuracy: 0.7473
# Epoch 51/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6628 - accuracy: 0.7912
# Epoch 52/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6673 - accuracy: 0.7692
# Epoch 53/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5476 - accuracy: 0.8242
# Epoch 54/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5049 - accuracy: 0.8132
# Epoch 55/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.4312 - accuracy: 0.8681
# Epoch 56/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3594 - accuracy: 0.8681
# Epoch 57/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.7982 - accuracy: 0.6923
# Epoch 58/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.5425 - accuracy: 0.5385
# Epoch 59/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.9788 - accuracy: 0.6923
# Epoch 60/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.1528 - accuracy: 0.6264
# Epoch 61/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.6929 - accuracy: 0.4176
# Epoch 62/100
# 2/2 [==============================] - 4s 1s/step - loss: 2.4196 - accuracy: 0.3297
# Epoch 63/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3242 - accuracy: 0.3407
# Epoch 64/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3844 - accuracy: 0.3077
# Epoch 65/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.3240 - accuracy: 0.3516
# Epoch 66/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2799 - accuracy: 0.4725
# Epoch 67/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2388 - accuracy: 0.5055
# Epoch 68/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.2457 - accuracy: 0.3407
# Epoch 69/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.1815 - accuracy: 0.4835
# Epoch 70/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.1339 - accuracy: 0.5604
# Epoch 71/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.0759 - accuracy: 0.5824
# Epoch 72/100
# 2/2 [==============================] - 4s 1s/step - loss: 1.0213 - accuracy: 0.5934
# Epoch 73/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.9660 - accuracy: 0.5934
# Epoch 74/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.9533 - accuracy: 0.5824
# Epoch 75/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.9646 - accuracy: 0.5604
# Epoch 76/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.8537 - accuracy: 0.6593
# Epoch 77/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.8746 - accuracy: 0.6264
# Epoch 78/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.6987 - accuracy: 0.7582
# Epoch 79/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5817 - accuracy: 0.8132
# Epoch 80/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5648 - accuracy: 0.7582
# Epoch 81/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.4912 - accuracy: 0.8571
# Epoch 82/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5172 - accuracy: 0.8462
# Epoch 83/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3972 - accuracy: 0.8242
# Epoch 84/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3973 - accuracy: 0.8681
# Epoch 85/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3680 - accuracy: 0.8571
# Epoch 86/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.3056 - accuracy: 0.9231
# Epoch 87/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.2286 - accuracy: 0.9560
# Epoch 88/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.1509 - accuracy: 0.9780
# Epoch 89/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.1605 - accuracy: 0.9451
# Epoch 90/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.1902 - accuracy: 0.9011
# Epoch 91/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.4904 - accuracy: 0.8352
# Epoch 92/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.5161 - accuracy: 0.8462
# Epoch 93/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.1794 - accuracy: 0.9560
# Epoch 94/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.1653 - accuracy: 0.9780
# Epoch 95/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.1764 - accuracy: 0.9341
# Epoch 96/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.1010 - accuracy: 0.9780
# Epoch 97/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.1107 - accuracy: 0.9670
# Epoch 98/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 99/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.0813 - accuracy: 0.9780
# Epoch 100/100
# 2/2 [==============================] - 4s 1s/step - loss: 0.0359 - accuracy: 1.0000

# %% [markdown]
# # Vẽ đồ thị

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %% [markdown]
# # Kiểm tra

# %%
test = 15
plt.imshow(cv2.cvtColor(x_pre[test], cv2.COLOR_BGR2RGB))
print(x_pre[test].shape)
img = x_pre[test].reshape(1,150,150,3)
img = img.astype('float32')
img /= 255
pred = np.argmax(model.predict(img), axis = 1)
print(pred)
Label = ['Cảm xúc buồn', 'Cảm xúc ghê tởm', 'Cảm xúc hạnh phúc', 'Cảm xúc sợ hãi']
Label[pred[0]]
# Out:
# (150, 150, 3)
# [0]
# 'Cảm xúc buồn'

# %%
img = cv2.resize(cv2.imread('CDV.jpg'), (150,150))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), cmap=plt.get_cmap('gray'))
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img /= 255
pred = np.argmax(model.predict(img), axis = 1)
print(pred)
Label = ['Cảm xúc buồn', 'Cảm xúc ghê tởm', 'Cảm xúc hạnh phúc', 'Cảm xúc sợ hãi']
Label[pred[0]]
# Out:
# [0]
# 'Cảm xúc buồn'

# %%
#Link: https://drive.google.com/drive/folders/1ydgXSt7wIOe_moy97Mmqvb_bbA1tZukk?usp=sharing
